# %%
# bb policy 改善のためのテスト場

# %%
import numpy as np
from OandaTrade import OandaTrade
import datetime
import time
from mod_bb import Trade, bbSimulate
from OANDA_FUNC_CONF import Data
import matplotlib.pyplot as plt

# %%
from Run_bbPolicy import testOptPolicy

# %%
testOptPolicy()
# Out:
# [(('M30', 170), (2.6, 0.88, 0.49)), (('H2', 40), (1.51, 0.87, 0.49)), (('M30', 140), (4.19, 0.88, 0.48)), (('M30', 130), (2.16, 0.84, 0.47)), (('H1', 70), (3.85, 0.87, 0.47)), (('H1', 160), (2.07, 0.83, 0.47)), (('H2', 80), (2.47, 0.83, 0.47)), (('M30', 160), (4.36, 0.86, 0.46)), (('H1', 80), (3.63, 0.84, 0.46)), (('M30', 120), (1.63, 0.78, 0.45)), (('M30', 150), (3.28, 0.83, 0.45)), (('H1', 60), (3.1, 0.78, 0.45)), (('H1', 170), (2.79, 0.82, 0.45)), (('H2', 30), (3.43, 0.8, 0.45)), (('M30', 110), (1.49, 0.77, 0.44)), (('H1', 50), (4.06, 0.78, 0.44)), (('H1', 180), (1.95, 0.89, 0.44)), (('H2', 90), (2.17, 0.89, 0.44)), (('H2', 100), (2.36, 0.89, 0.44)), (('M30', 180), (0.96, 0.78, 0.42)), (('M30', 90), (1.19, 0.74, 0.4)), (('M30', 190), (-0.35, 0.75, 0.4)), (('M30', 200), (0.27, 0.75, 0.4)), (('M30', 230), (1.36, 0.79, 0.4)), (('M30', 240), (1.45, 0.79, 0.4)), (('H1', 90), (-0.26, 0.75, 0.4)), (('H1', 100), (0.08, 0.75, 0.4)), (('M30', 100), (2.21, 0.7, 0.39)), (('M30', 210), (-0.11,
# ...

# %%
SPAN, bWindow = ('M30', 170)

# %%
data = Data(SPAN, 5000)
bb = data.bband(window=bWindow)

# %%
fig = bb[["raw", "upper", "lower"]].plot(figsize=(70,10), grid=True, title="title").get_figure()

# %%
fig.tight_layout()

# %%
fig

# %%
date_time = datetime.datetime.now().strftime("%m/%d/%Y, %H:%M:%S")

# %%
date_time
# Out:
# '09/28/2021, 00:29:21'

# %%
# sorting test
s = [[1,1],[2,2],[3,1],[2,1],[1,2]]

# %%
ss = sorted(s, key=lambda x : x[0] )
sorted(ss, key=lambda x : x[1] )
# Out:
# [[1, 1], [2, 1], [3, 1], [1, 2], [2, 2]]

# %%
s
# Out:
# [[1, 1], [2, 2], [3, 1], [2, 1], [1, 2]]
