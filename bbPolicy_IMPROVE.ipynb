# %%
# bb policy 改善のためのテスト場

# %%
import numpy as np
from OandaTrade import OandaTrade
import datetime
import time
from mod_bb import Trade, bbSimulate
from OANDA_FUNC_CONF import Data
import matplotlib.pyplot as plt

# %%
from Run_bbPolicy import getOptPolicy

# %%
getOptPolicy()
# Out:
# [(('H1', 170), (7.17, 0.92)), (('M30', 240), (6.83, 0.93)), (('M30', 230), (6.61, 0.93)), (('M30', 140), (6.46, 0.91)), (('H1', 70), (6.34, 0.9)), (('M30', 160), (6.21, 0.95)), (('M30', 280), (6.2, 0.92)), (('M30', 290), (6.09, 0.92)), (('H1', 80), (5.75, 0.94)), (('M30', 180), (5.65, 0.89)), (('M30', 150), (5.6, 0.86)), (('M30', 220), (5.47, 0.87)), (('M30', 200), (5.3, 0.88)), (('M30', 170), (5.28, 0.94)), (('H2', 70), (5.01, 0.9)), (('M30', 210), (5.0, 0.87)), (('H1', 150), (4.98, 0.9)), (('H2', 80), (4.91, 0.9)), (('M30', 250), (4.89, 0.92)), (('H1', 160), (4.86, 0.9)), (('H1', 120), (4.83, 0.91)), (('H1', 140), (4.78, 0.9)), (('H1', 190), (4.71, 0.88)), (('H2', 100), (4.68, 0.88)), (('M30', 270), (4.57, 0.9)), (('H1', 200), (4.52, 0.88)), (('H1', 100), (4.46, 0.88)), (('M30', 190), (4.43, 0.88)), (('H2', 90), (4.41, 0.88)), (('H2', 290), (4.41, 1.0)), (('H2', 280), (4.4, 1.0)), (('H2', 40), (4.36, 0.93)), (('H1', 180), (4.19, 0.88)), (('H2', 60), (4.0, 0.9)), (('H2', 270), (3.95, 1.0)), (('H2', 50), (3.93, 0.86)), (('H1', 130), (3.86, 0.9)), (('H1', 90), (3.85, 0.88)), (('M30', 260), (3.7, 0.9)), (('H2', 260), (3.69, 1.0)), (('H2', 250), (3.51, 1.0)), (('H2', 230), (3.49, 1.0)), (('H2', 220), (3.44, 1.0)), (('H2', 240), (3.18, 1.0))]
# ('H1', 170)
# ('H1', 170)

# %%
SPAN = "H1"
bWindow = 170

# %%
data = Data(SPAN, 5000)
bb = data.bband(window=bWindow)

# %%
fig = bb[["raw", "upper", "lower"]].plot(figsize=(70,10), grid=True, title="title").get_figure()

# %%
fig.tight_layout()

# %%
fig

# %%
date_time = datetime.datetime.now().strftime("%m/%d/%Y, %H:%M:%S")

# %%
date_time
# Out:
# '09/28/2021, 00:29:21'
